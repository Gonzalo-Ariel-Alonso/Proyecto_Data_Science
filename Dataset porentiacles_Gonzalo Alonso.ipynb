# %% [markdown]
# # Posibles DataSets para proyecto de ciencia de datos

# %%
import pandas as pd

# %% [markdown]
# ##  1 - Company Bankruptcy Prediction Data set
# En este data set tenemos 95 columnas de informacion financiera y diferentes indices de varias empresas de las cuales algunas han quebrado, analizando esta informacion se desea encontrar si existe algun patron o indicio de cuales son los datos mas importantes a la hora de saber si una empresa podria llegar a estar por quebrar.

# %%
CBP = pd.read_csv('Company Bankruptcy Prediction.csv')

# %%
# Dataset
CBP
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# ...

# %%
# Informacion
CBP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6819 entries, 0 to 6818
# Data columns (total 96 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Bankrupt?                                                 6819 non-null   int64
#  1    ROA(C) before interest and depreciation before interest  6819 non-null   float64
#  2    ROA(A) before interest and % after tax                   6819 non-null   float64
#  3    ROA(B) before interest and depreciation after tax        6819 non-null   float64
#  4    Operating Gross Margin                                   6819 non-null   float64
#  5    Realized Sales Gross Margin                              6819 non-null   float64
#  6    Operating Profit Rate                                    6819 non-null   float64
#  7    Pre-tax net Interest Rate                                6819 non-null   float64
# ...

# %% [markdown]
# ## 2 - Freelance Platform Projects
# La informacion de este data set proviene de la pagina web https://www.peopleperhour.com/ en la cual profecionales o particulares pueden contratar los servicios de trabajadores freelance que posean mucha o poca experiencia segun sea necesario a cambio de un presupuesto pactado. Con esta informacion se pueden buscar tendencias de cuales son los trabajos con mayor demanda, cuales son los de menor oferta, los mejores pagados en base a que tanta experiencia se requiere, entre otras.

# %%
FLPP = pd.read_csv('Freelance Platform Projects.csv')

# %%
# Data set
FLPP
# Out:
#                                                   Title  \
# 0     Only living in USA, 10 freelancers needed, eas...
# 1     A hand-drawn whiteboard animation explainer video
# 2                                I need an animated GIF
# 3                             Client Services Assistant
# 4     1st project - 1 page wordpress site set up wit...
# ...                                                 ...
# 9098  Published Travel Writer required for content c...
# 9099  Shopify - Filtering Work (Product Selection/No...
# 9100                                   Simple SQL Query
# 9101  Create a Carbon, Water, Waste Calculating plat...
# 9102                                  COMPANY REGISTERS
#
#                  Category Name         Experience          Sub Category Name  \
# 0                     Business          Entry ($)  Administration Assistance
# 1                       Design       Expert ($$$)                  Animation
# ...

# %%
#Informacion
FLPP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9103 entries, 0 to 9102
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Title                      9103 non-null   object
#  1   Category Name              9103 non-null   object
#  2   Experience                 9103 non-null   object
#  3   Sub Category Name          9103 non-null   object
#  4   Currency                   9103 non-null   object
#  5   Budget                     9103 non-null   float64
#  6   Location                   9103 non-null   object
#  7   Freelancer Preferred From  9103 non-null   object
#  8   Type                       9103 non-null   object
#  9   Date Posted                9103 non-null   object
#  10  Description                9103 non-null   object
#  11  Duration                   1201 non-null   object
#  12  Client Registration Date   9103 non-null   object
# ...

# %% [markdown]
# ## 3 - Credit Card Fraud Detection
# En este ultimo dataset tenemos informacion de las transacciones hechas con tarjetas de credito de las cuales se sabe cuales son y no son fraudulentas, si bien la mayor parte de los datos estan encriptada por temas de confidencialidad, aun se puede utilizar para buscar patrones que den indicios de cuales transacciones son o no son fraudulentas.

# %%
CCFD = pd.read_csv('creditcard.csv' )

# %%
# Data set
CCFD
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
# Informacion
CCFD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...
